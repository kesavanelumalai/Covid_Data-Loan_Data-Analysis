# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("covid-data.csv")

# %%
df
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df.head(10)
# Out:
#   iso_code continent     location      date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  31/12/19          NaN        0.0
# 1      AFG      Asia  Afghanistan  01/01/20          NaN        0.0
# 2      AFG      Asia  Afghanistan  02/01/20          NaN        0.0
# 3      AFG      Asia  Afghanistan  03/01/20          NaN        0.0
# 4      AFG      Asia  Afghanistan  04/01/20          NaN        0.0
# 5      AFG      Asia  Afghanistan  05/01/20          NaN        0.0
# 6      AFG      Asia  Afghanistan  06/01/20          NaN        0.0
# 7      AFG      Asia  Afghanistan  07/01/20          NaN        0.0
# 8      AFG      Asia  Afghanistan  08/01/20          NaN        0.0
# 9      AFG      Asia  Afghanistan  09/01/20          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# ...

# %% [markdown]
# # High level data understanding
#
# ## a.find no of rows & columns in the dataset

# %%
df.shape
# Out:
# (57394, 49)

# %% [markdown]
# ##  b. data types of columns

# %%
df.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %% [markdown]
# ## C.) info and describe of data in dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %% [markdown]
# # 3. Low Level data Unerstanding

# %% [markdown]
# ## a.) find count of unique values in location column

# %%
df['location'].nunique()
# Out:
# 216

# %% [markdown]
# #### b.) find which continent has maximum frequency using values counts

# %%
df['continent'].value_counts()
# Out:
# continent
# Europe           14828
# Africa           13637
# Asia             13528
# North America     9116
# South America     3404
# Oceania           2235
# Name: count, dtype: int64

# %% [markdown]
# #### c.) find the maximum and mean values in total_cases

# %%
df['total_cases'].max()
# Out:
# np.float64(55154651.0)

# %%
df['total_cases'].mean()
# Out:
# np.float64(167797.3688753302)

# %%
df['total_cases'].min()
# Out:
# np.float64(1.0)

# %% [markdown]
# #### d.) find the 25% ,50% and 75% quartilr value in "total_deaths"

# %%
df['total_deaths'].describe().round()
# Out:
# count      44368.0
# mean        6859.0
# std        55781.0
# min            1.0
# 25%           13.0
# 50%           84.0
# 75%          727.0
# max      1328537.0
# Name: total_deaths, dtype: float64

# %% [markdown]
# #### e.) find which continent has maximum 'human_devolepment_inex'

# %%
df.groupby("continent").agg({"human_development_index":"max"}).head()
# Out:
#                human_development_index
# continent
# Africa                           0.797
# Asia                             0.933
# Europe                           0.953
# North America                    0.926
# Oceania                          0.939

# %% [markdown]
# #### f.) find which continent has maximum 'gp_per_capita'

# %%
df.groupby("continent").agg({'gdp_per_capita':'min'}).head()
# Out:
#                gdp_per_capita
# continent
# Africa                661.240
# Asia                 1479.147
# Europe               5189.972
# North America        1653.173
# Oceania              2205.923

# %% [markdown]
# ## 4. Filter the dataframe with only this columns
# ['continent','location','date','total_cases','total_deaths','gdp_per_ca
# pita','
# human_development_index'] and update the data frame.

# %%
df=df[['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index']]

# %%
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# ## 5.) data cleaning

# %% [markdown]
# #### a.) ramove all duplicates observation

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# #### b.) find missing values in all columns

# %%
df.isnull().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %% [markdown]
# #### c.) Remove all observations where continent column value is missing

# %%
df.dropna()
df.dropna(subset=["continent"])
# Out:
#       continent     location      date  total_cases  total_deaths  \
# 0          Asia  Afghanistan  31/12/19          NaN           NaN
# 1          Asia  Afghanistan  01/01/20          NaN           NaN
# 2          Asia  Afghanistan  02/01/20          NaN           NaN
# 3          Asia  Afghanistan  03/01/20          NaN           NaN
# 4          Asia  Afghanistan  04/01/20          NaN           NaN
# ...         ...          ...       ...          ...           ...
# 56743    Africa     Zimbabwe  13/11/20       8696.0         255.0
# 56744    Africa     Zimbabwe  14/11/20       8765.0         257.0
# 56745    Africa     Zimbabwe  15/11/20       8786.0         257.0
# 56746    Africa     Zimbabwe  16/11/20       8786.0         257.0
# 56747    Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# #### d.) fill all missing values with 0

# %%
df=df.fillna(0)
df
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          0.0           0.0
# 1          Asia    Afghanistan  01/01/20          0.0           0.0
# 2          Asia    Afghanistan  02/01/20          0.0           0.0
# 3          Asia    Afghanistan  03/01/20          0.0           0.0
# 4          Asia    Afghanistan  04/01/20          0.0           0.0
# ...         ...            ...       ...          ...           ...
# 57389         0  International  13/11/20        696.0           7.0
# 57390         0  International  14/11/20        696.0           7.0
# 57391         0  International  15/11/20        696.0           7.0
# 57392         0  International  16/11/20        696.0           7.0
# 57393         0  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %%
df.isnull().sum()
# Out:
# continent                  0
# location                   0
# date                       0
# total_cases                0
# total_deaths               0
# gdp_per_capita             0
# human_development_index    0
# dtype: int64

# %% [markdown]
# ## 6. Date time format :
# #### a. Convert date column in datetime format using pandas.to_datetime

# %%
df['date']=pd.to_datetime(df['date'])
df
# Out:
#       continent       location       date  total_cases  total_deaths  \
# 0          Asia    Afghanistan 2019-12-31          0.0           0.0
# 1          Asia    Afghanistan 2020-01-01          0.0           0.0
# 2          Asia    Afghanistan 2020-02-01          0.0           0.0
# 3          Asia    Afghanistan 2020-03-01          0.0           0.0
# 4          Asia    Afghanistan 2020-04-01          0.0           0.0
# ...         ...            ...        ...          ...           ...
# 57389         0  International 2020-11-13        696.0           7.0
# 57390         0  International 2020-11-14        696.0           7.0
# 57391         0  International 2020-11-15        696.0           7.0
# 57392         0  International 2020-11-16        696.0           7.0
# 57393         0  International 2020-11-17        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# ...

# %%
df.dtypes
# Out:
# continent                          object
# location                           object
# date                       datetime64[ns]
# total_cases                       float64
# total_deaths                      float64
# gdp_per_capita                    float64
# human_development_index           float64
# dtype: object

# %% [markdown]
# #### b. Create new column month after extracting month data from date column.

# %%
df['month']=pd.DatetimeIndex(df['date']).month
df
# Out:
#       continent       location       date  total_cases  total_deaths  \
# 0          Asia    Afghanistan 2019-12-31          0.0           0.0
# 1          Asia    Afghanistan 2020-01-01          0.0           0.0
# 2          Asia    Afghanistan 2020-02-01          0.0           0.0
# 3          Asia    Afghanistan 2020-03-01          0.0           0.0
# 4          Asia    Afghanistan 2020-04-01          0.0           0.0
# ...         ...            ...        ...          ...           ...
# 57389         0  International 2020-11-13        696.0           7.0
# 57390         0  International 2020-11-14        696.0           7.0
# 57391         0  International 2020-11-15        696.0           7.0
# 57392         0  International 2020-11-16        696.0           7.0
# 57393         0  International 2020-11-17        696.0           7.0
#
#        gdp_per_capita  human_development_index  month
# 0            1803.987                    0.498     12
# ...

# %% [markdown]
# ## 7.) Data Aggregation:
# #### a.) Find max value in all columns using groupby function on 'continent' column

# %%
df.groupby('continent').max().reset_index()
# Out:
#        continent                      location       date  total_cases  \
# 0              0                         World 2020-12-11   55154651.0
# 1         Africa                      Zimbabwe 2020-12-11     752269.0
# 2           Asia                         Yemen 2020-12-11    8874290.0
# 3         Europe                       Vatican 2020-12-11    1991233.0
# 4  North America  United States Virgin Islands 2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 6  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0     1328537.0       15469.207                    0.000     12
# 1       20314.0       26382.287                    0.797     12
# 2      130519.0      116935.600                    0.933     12
# 3       52147.0       94277.965                    0.953     12
# 4      247220.0       54225.446                    0.926     12
# ...

# %% [markdown]
# #### b.) Store the result in a new dataframe named 'df_groupby'.

# %%
df_groupby=df.groupby('continent').max().reset_index()

# %%
df_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0              0                         World 2020-12-11   55154651.0
# 1         Africa                      Zimbabwe 2020-12-11     752269.0
# 2           Asia                         Yemen 2020-12-11    8874290.0
# 3         Europe                       Vatican 2020-12-11    1991233.0
# 4  North America  United States Virgin Islands 2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 6  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month
# 0     1328537.0       15469.207                    0.000     12
# 1       20314.0       26382.287                    0.797     12
# 2      130519.0      116935.600                    0.933     12
# 3       52147.0       94277.965                    0.953     12
# 4      247220.0       54225.446                    0.926     12
# ...

# %% [markdown]
# ## 8.) Feature Engineering :
# #### a.) Create a new feature 'total_deaths_to_total_cases' by ratio of 'total_deaths' column to 'total_cases'

# %%
df_groupby["total_deaths_to_totals_cases"]=df_groupby["total_deaths"]/df_groupby["total_cases"]

# %%
df_groupby["total_deaths_to_totals_cases"]*100
# Out:
# 0    2.408749
# 1    2.700364
# 2    1.470754
# 3    2.618830
# 4    2.206241
# 5    3.268468
# 6    2.825066
# Name: total_deaths_to_totals_cases, dtype: float64

# %%
df_groupby
# Out:
#        continent                      location       date  total_cases  \
# 0              0                         World 2020-12-11   55154651.0
# 1         Africa                      Zimbabwe 2020-12-11     752269.0
# 2           Asia                         Yemen 2020-12-11    8874290.0
# 3         Europe                       Vatican 2020-12-11    1991233.0
# 4  North America  United States Virgin Islands 2020-12-11   11205486.0
# 5        Oceania             Wallis and Futuna 2020-12-11      27750.0
# 6  South America                     Venezuela 2020-12-11    5876464.0
#
#    total_deaths  gdp_per_capita  human_development_index  month  \
# 0     1328537.0       15469.207                    0.000     12
# 1       20314.0       26382.287                    0.797     12
# 2      130519.0      116935.600                    0.933     12
# 3       52147.0       94277.965                    0.953     12
# 4      247220.0       54225.446                    0.926     12
# ...

# %% [markdown]
# ## 9.) Data Visualization :
# ### a.) Perform Univariate analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(df["gdp_per_capita"])
# Out:
# C:\Users\kesav\AppData\Local\Temp\ipykernel_29580\537543423.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["gdp_per_capita"])
# <Axes: xlabel='gdp_per_capita', ylabel='Density'>

# %% [markdown]
# #### b.) Plot a scatter plot of 'total_cases' & 'gdp_per_capita'

# %%
sns.jointplot(data=df_groupby,x="total_cases",y="gdp_per_capita",kind="scatter",color='green')

# %% [markdown]
# #### c. Plot Pairplot on df_groupby dataset.

# %%
sns.pairplot(data=df_groupby)

# %% [markdown]
# #### d. Plot a bar plot of 'continent' column with 'total_cases' .

# %%
sns.catplot(data=df_groupby,x="continent",y="total_cases",kind="bar")

# %% [markdown]
# # loan_data

# %%
df.to_csv("Covid_Data.csv")

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("loan_data_set.csv")

# %%
df.isnull().sum()
df.fillna(method="ffill",inplace=True)
df.fillna(method="bfill",inplace=True)
df1=pd.get_dummies(df,columns=["Gender","Married","Dependents","Education","Self_Employed","Property_Area","Loan_Status"])
df1.dtypes
df1.drop("Gender_Female",axis=1,inplace=True)
df1.drop("Married_No",axis=1,inplace=True)
df1.drop("Education_Graduate",axis=1,inplace=True)
df1.drop("Self_Employed_No",axis=1,inplace=True)
df1.drop("Property_Area_Rural",axis=1,inplace=True)
df1.drop("Loan_Status_N",axis=1,inplace=True)
df1.drop("Dependents_3+",axis=1,inplace=True)


x=df1.iloc[:,2:15]
y=df1.iloc[:,-1]

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=(0))

from sklearn.linear_model import LogisticRegression
m1=LogisticRegression()
m1.fit(x_train, y_train)
y_pred=m1.predict(x_test)

from sklearn.metrics import accuracy_score,confusion_matrix
acc=accuracy_score(y_test, y_pred)
c=confusion_matrix(y_test,y_pred)
print(acc)
print(c)
# Out:
# C:\Users\kesav\AppData\Local\Temp\ipykernel_29580\3859756233.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill",inplace=True)
# C:\Users\kesav\AppData\Local\Temp\ipykernel_29580\3859756233.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill",inplace=True)
# 0.8506493506493507
# [[ 23  20]
#  [  3 108]]
# C:\Users\kesav\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
